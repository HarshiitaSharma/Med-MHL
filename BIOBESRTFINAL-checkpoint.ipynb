# %%
# !pip install transformers datasets torch scikit-learn --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\harshita\appdata\roaming\python\python313\site-packages (4.51.3)
# Requirement already satisfied: datasets in c:\users\harshita\appdata\roaming\python\python313\site-packages (3.5.1)
# Requirement already satisfied: torch in c:\users\harshita\appdata\roaming\python\python313\site-packages (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\harshita\appdata\roaming\python\python313\site-packages (1.6.1)
# Requirement already satisfied: filelock in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (3.11.18)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\harshita\appdata\roaming\python\python313\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\harshita\appdata\roaming\python\python313\site-packages (from torch) (80.0.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: idna>=2.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\harshita\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Load datasets
def load_data(base_path):
    train = pd.read_csv(f"{base_path}/train.csv")
    dev = pd.read_csv(f"{base_path}/dev.csv") 
    test = pd.read_csv(f"{base_path}/test.csv")
    return train, dev, test

base_path = r"C:\Users\Harshita\OneDrive\Desktop\Med-MMHL\fakenews_article"
train_df, dev_df, test_df = load_data(base_path)

# Verify data
print(f"Train: {len(train_df)}, Dev: {len(dev_df)}, Test: {len(test_df)}")
print("Sample:\n", train_df[["content", "det_fake_label"]].head())
# Out:
# Train: 8309, Dev: 1189, Test: 2375
# Sample:
#                                               content  det_fake_label
# 0  "Five photos have been shared thousands of tim...               1
# 1  The development of effective anti-androgen the...               0
# 2  "\nThis presentation is particularly unfortuna...               0
# 3  Oct. 7, 2022 – Moms who consume ultra-processe...               0
# 4  Why do some people with cold sores around thei...               0

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

model_name = "dmis-lab/biobert-v1.1"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=2,
    problem_type="single_label_classification"
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at dmis-lab/biobert-v1.1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from datasets import Dataset

def prepare_datasets(df):
    return Dataset.from_pandas(df[["content", "det_fake_label"]])

train_ds = prepare_datasets(train_df)
dev_ds = prepare_datasets(dev_df)
test_ds = prepare_datasets(test_df)

def tokenize(batch):
    return tokenizer(
        batch["content"],
        padding="max_length",
        truncation=True,
        max_length=256
    )

tokenized_train = train_ds.map(tokenize, batched=True)
tokenized_dev = dev_ds.map(tokenize, batched=True)
tokenized_test = test_ds.map(tokenize, batched=True)
# Out:
# Map:   0%|          | 0/8309 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1189 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2375 [00:00<?, ? examples/s]

# %%
# !pip install transformers datasets torch scikit-learn --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in c:\users\harshita\appdata\roaming\python\python313\site-packages (4.51.3)
# Requirement already satisfied: datasets in c:\users\harshita\appdata\roaming\python\python313\site-packages (3.5.1)
# Requirement already satisfied: torch in c:\users\harshita\appdata\roaming\python\python313\site-packages (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\harshita\appdata\roaming\python\python313\site-packages (1.6.1)
# Requirement already satisfied: filelock in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in c:\users\harshita\appdata\roaming\python\python313\site-packages (from datasets) (3.11.18)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\harshita\appdata\roaming\python\python313\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\harshita\appdata\roaming\python\python313\site-packages (from torch) (80.0.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: idna>=2.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\harshita\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\harshita\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_dev,
    compute_metrics=compute_metrics,
    tokenizer=tokenizer
)

# Version-aware training loop
if TRANSFORMERS_VERSION >= version.parse("4.4.0"):
    # Modern versions with built-in progress
    trainer.train()
else:
    # Manual progress for older versions
    for epoch in range(training_args.num_train_epochs):
        print(f"\nEpoch {epoch + 1}/{training_args.num_train_epochs}")
        trainer.train()
        metrics = trainer.evaluate()
        print(f"Validation Accuracy: {metrics['eval_accuracy']:.2%}")
# Out:
# C:\Users\Harshita\AppData\Local\Temp\ipykernel_31504\58197681.py:3: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# C:\Users\Harshita\AppData\Roaming\Python\Python313\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='3118' max='3117' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3117/3117 5:54:58, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.709300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.693000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.665800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.607200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.559300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.497100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.541100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.438400</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.560600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.488700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.438000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.538700</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.489200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.474100</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.538600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.340300</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.332900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.483200</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.458400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.285000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.386000</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.362200</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.474900</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.431500</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.236100</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.281400</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.399900</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.447900</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.382200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.333800</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.364300</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.367000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.350000</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.293100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.457500</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.346300</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.355800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.579200</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.389600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.247600</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.271900</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.315900</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.296300</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.399300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.304600</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.299000</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.368400</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.417400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.278300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.267600</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.247400</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.320500</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.323700</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.257600</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.233600</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.448400</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.325200</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.242600</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.501000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.325500</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.257300</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.166500</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.204100</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.320900</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.272500</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.308700</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.296000</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.346100</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.309000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.179300</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.305100</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.238600</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.193700</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.346000</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.313500</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.390500</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.268200</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.189300</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.229600</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.327600</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.318900</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.265000</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.370100</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.440200</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.231900</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.416500</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.171000</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.225500</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.386600</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.180000</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.250700</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.250800</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.264100</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.177700</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.159500</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.401600</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.371700</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.209300</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.247600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.405700</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.387500</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.244200</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.345900</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.134200</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.234600</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.135200</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.228200</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.273600</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.215800</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.342900</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.148900</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.317600</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.343300</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.142800</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.286400</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.149600</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.175800</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.212300</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.237700</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.125200</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.122200</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.235300</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.242900</td>
#     </tr>
#     <tr>
#       <td>1
# C:\Users\Harshita\AppData\Roaming\Python\Python313\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# C:\Users\Harshita\AppData\Roaming\Python\Python313\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# Cell In[28], line 15
#      12 # Version-aware training loop
#      13 if TRANSFORMERS_VERSION >= version.parse("4.4.0"):
#      14     # Modern versions with built-in progress
# ---> 15     trainer.train()
#      16 else:
#      17     # Manual progress for older versions
#      18     for epoch in range(training_args.num_train_epochs):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\trainer.py:2245, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243         hf_hub_utils.enable_progress_bars()
#    2244 else:
# -> 2245     return inner_training_loop(
#    2246         args=args,
#    2247         resume_from_checkpoint=resume_from_checkpoint,
#    2248         trial=trial,
#    2249         ignore_keys_for_eval=ignore_keys_for_eval,
#    2250     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\trainer.py:2627, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2625     self.state.epoch = epoch + (step + 1 + steps_skipped) / steps_in_epoch
#    2626     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 2627     self._maybe_log_save_evaluate(
#    2628         tr_loss,
#    2629         grad_norm,
#    2630         model,
#    2631         trial,
#    2632         epoch,
#    2633         ignore_keys_for_eval,
#    2634         start_time,
#    2635         learning_rate=learning_rate,
#    2636     )
#    2637 else:
#    2638     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\trainer.py:3103, in Trainer._maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval, start_time, learning_rate)
#    3100         self.control.should_save = is_new_best_metric
#    3102 if self.control.should_save:
# -> 3103     self._save_checkpoint(model, trial)
#    3104     self.control = self.callback_handler.on_save(self.args, self.state, self.control)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\trainer.py:3200, in Trainer._save_checkpoint(self, model, trial)
#    3198 run_dir = self._get_output_dir(trial=trial)
#    3199 output_dir = os.path.join(run_dir, checkpoint_folder)
# -> 3200 self.save_model(output_dir, _internal_call=True)
#    3202 if self.args.save_strategy in [SaveStrategy.STEPS, SaveStrategy.EPOCH] and self.state.best_global_step:
#    3203     best_checkpoint_folder = f"{PREFIX_CHECKPOINT_DIR}-{self.state.best_global_step}"
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\trainer.py:3902, in Trainer.save_model(self, output_dir, _internal_call)
#    3899         self.model_wrapped.save_checkpoint(output_dir)
#    3901 elif self.args.should_save:
# -> 3902     self._save(output_dir)
#    3904 # Push to the Hub when `save_model` is called by the user.
#    3905 if self.args.push_to_hub and not _internal_call:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\trainer.py:4006, in Trainer._save(self, output_dir, state_dict)
#    4004             torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    4005 else:
# -> 4006     self.model.save_pretrained(
#    4007         output_dir, state_dict=state_dict, safe_serialization=self.args.save_safetensors
#    4008     )
#    4010 if self.processing_class is not None:
#    4011     self.processing_class.save_pretrained(output_dir)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\transformers\modeling_utils.py:3564, in PreTrainedModel.save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    3559     gc.collect()
#    3561 if safe_serialization:
#    3562     # At some point we will need to deal better with save_function (used for TPU and other distributed
#    3563     # joyfulness), but for now this enough.
# -> 3564     safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    3565 else:
#    3566     save_function(shard, os.path.join(save_directory, shard_file))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\safetensors\torch.py:286, in save_file(tensors, filename, metadata)
#     255 def save_file(
#     256     tensors: Dict[str, torch.Tensor],
#     257     filename: Union[str, os.PathLike],
#     258     metadata: Optional[Dict[str, str]] = None,
#     259 ):
#     260     """
#     261     Saves a dictionary of tensors into raw bytes in safetensors format.
#     262
#    (...)    284     ```
#     285     """
# --> 286     serialize_file(_flatten(tensors), filename, metadata=metadata)
#
# SafetensorError: Error while serializing: IoError(Os { code: 112, kind: StorageFull, message: "There is not enough space on the disk." })
